# %% [markdown]
# # SupplyIQ — Delivery Delay & Route Risk Predictor
# Day 19 Project Initialization

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv('/content/drive/MyDrive/supply_chain_data.csv')
df.head()

# %%
print(df.shape)
df.info()

# %%
print(df.columns.tolist())

# %%
df.describe(include='all')

# %%
df.isnull().sum()

# %%
num=df.select_dtypes(include='number').columns
cat=df.select_dtypes(exclude='number').columns
print('Numerical:',list(num))
print('Categorical:',list(cat))

# %%
# Create target variable for classification
df['Route_Risk']=(df['Shipping times']>df['Shipping times'].median()).astype(int)
df['Route_Risk'].value_counts()

# %%
plt.figure(figsize=(8,4))
sns.countplot(x='Route_Risk',data=df)
plt.show()

# %% [markdown]
# ## Project Planning
#
# - Data Cleaning
# - Handle missing values
# - Encode categorical columns
# - Feature scaling if needed
# - Model: Random Forest Classifier
# - Metrics: Accuracy, Precision, Recall, F1-score

# %%
print('Dataset Name: Supply Chain Analysis')
print('Rows:',df.shape[0])
print('Columns:',df.shape[1])
print('Target Variable: Route_Risk')
